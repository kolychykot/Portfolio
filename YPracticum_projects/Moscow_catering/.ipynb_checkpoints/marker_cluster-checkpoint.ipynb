# %% [markdown]
# # Кластеры. Когда нужно больше точек

# %% [markdown]
# Используем набор данных `moscow_malls_info.csv` с информацией о торговых центрах Москвы.
#
# Датасет хранит следующие данные:
#
# - `name` — название торгового центра;
# - `address` — адрес торгового центра;
# - `hours` — часы работы торгового центра;
# - `lat` — широта точки, в которой находится объект;
# - `lng` — долгота точки, в которой находится объект;
# - `rating` — рейтинг центра на Яндекс Картах;
# - `district` — район Москвы, в котором находится объект.
#
# Исследуем набор данных:

# %%
import pandas as pd

df = pd.read_csv('/datasets/moscow_malls_info.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 786 entries, 0 to 785
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      786 non-null    object
#  1   address   786 non-null    object
#  2   hours     685 non-null    object
#  3   lat       786 non-null    float64
#  4   lng       786 non-null    float64
#  5   rating    786 non-null    float64
#  6   district  764 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 43.1+ KB

# %% [markdown]
# Датасет хранит информацию о 786 торговых центрах.
#
# Посмотрим на первые строки:

# %%
df.head()
# Out:
#         name                                   address  \
# 0  Капитолий           Москва, Правобережная улица, 1Б
# 1     Dexter  Москва, МКАД, 78-й километр, 14, корп. 1
# 2        РИО  Москва, Дмитровское шоссе, 163А, корп. 1
# 3    Экстрим               Москва, Смольная улица, 63Б
# 4  Discovery                Москва, улица Дыбенко, 7/1
#
#                     hours        lat        lng  rating  \
# 0  ежедневно, 10:00–22:00  55.880803  37.449824     4.7
# 1  ежедневно, 10:00–21:00  55.893082  37.501263     4.3
# 2  ежедневно, 10:00–22:00  55.909388  37.539546     4.8
# 3  ежедневно, 10:00–21:00  55.869937  37.469915     4.7
# 4  ежедневно, 09:00–21:00  55.878662  37.479251     4.3
#
#                                   district
# 0          Северный административный округ
# 1          Северный административный округ
# 2  Северо-Восточный административный округ
# 3          Северный административный округ
# 4          Северный административный округ

# %% [markdown]
# Отметим первые 5 заведений на карте:

# %%
# подключаем библиотеку
from folium import Marker, Map

# moscow_lat - широта, moscow_lng – долгота
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10, tiles='Cartodb Positron')

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его на карту
def create_marker(row):
    Marker([row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}"
    ).add_to(m)

# применяем функцию для создания маркера к первым 5 записям датафрейма
df[:5].apply(create_marker, axis=1)
    
# выводим карту
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4aed2245c091a4b5e8d5d169e3b8028b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4aed2245c091a4b5e8d5d169e3b8028b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4aed2245c091a4b5e8d5d169e3b8028b = L.map(
#                 &quot;map_4aed2245c091a4b5e8d5d169e3b8028b&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7651107c819206a86f0a43bfa4e6f528 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4aed2245c091a4b5e8d5d169e3b8028b);
#
#
#             var marker_1bf60470b0b36ca3e072b132ae9b5741 = L.marker(
#                 [55.880803, 37.449824],
#                 {}
#             ).addTo(map_4aed2245c091a4b5e8d5d169e3b8028b);
#
#
#         var popup_deb39a31ab035c1d07c62bc900c57335 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_01271f4eed20040d99aa1bbd99c30ea0 = $(`&lt;div id=&quot;html_01271f4eed20040d99aa1bbd99c30ea0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Капитолий 4.7&lt;/div&gt;`)[0];
#             popup_deb39a31ab035c1d07c62bc900c57335.setContent(html_01271f4eed20040d99aa1bbd99c30ea0);
#
#
#         marker_1bf60470b0b36ca3e072b132ae9b5741.bindPopup(popup_deb39a31ab035c1d07c62bc900c57335)
#         ;
#
#
#
#
#             var marker_6563dbf3b497134e5cec15ff6b556a6c = L.marker(
#                 [55.893082, 37.501263],
#                 {}
#             ).addTo(map_4aed2245c091a4b5e8d5d169e3b8028b);
#
#
#         var popup_869022cbdab4218ece186d4f6c33d4c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e8a0479cd466659fa415f468610c73d2 = $(`&lt;div id=&quot;html_e8a0479cd466659fa415f468610c73d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dexter 4.3&lt;/div&gt;`)[0];
#             popup_869022cbdab4218ece186d4f6c33d4c0.setContent(html_e8a0479cd466659fa415f468610c73d2);
#
#
#         marker_6563dbf3b497134e5cec15ff6b556a6c.bindPopup(popup_869022cbdab4218ece186d4f6c33d4c0)
#         ;
#
#
#
#
#             var marker_6b2f0fca74bad09047adbf8579a32183 = L.marker(
#                 [55.909388, 37.539546],
#                 {}
#             ).addTo(map_4aed2245c091a4b5e8d5d169e3b8028b);
#
#
#         var popup_a23cc580dd31bfb56083c6b3c10300c7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a99518598b7a35a5e5cb4d6ae95217e8 = $(`&lt;div id=&quot;html_a99518598b7a35a5e5cb4d6ae95217e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;РИО 4.8&lt;/div&gt;`)[0];
#             popup_a23cc580dd31bfb56083c6b3c10300c7.setContent(html_a99518598b7a35a5e5cb4d6ae95217e8);
#
#
#         marker_6b2f0fca74bad09047adbf8579a32183.bindPopup(popup_a23cc580dd31bfb56083c6b3c10300c7)
#         ;
#
#
#
#
#             var marker_f691c8b8c5854ed9709c7399bb478b54 = L.marker(
#                 [55.869937, 37.469915],
#                 {}
#             ).addTo(map_4aed2245c091a4b5e8d5d169e3b8028b);
#
#
#         var popup_e136f1d6cd0bdcf233c45241c5ea8fc9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_cfe128880dca41311c6e7ce2958a3dcb = $(`&lt;div id=&quot;html_cfe128880dca41311c6e7ce2958a3dcb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Экстрим 4.7&lt;/div&gt;`)[0];
#             popup_e136f1d6cd0bdcf233c45241c5ea8fc9.setContent(html_cfe128880dca41311c6e7ce2958a3dcb);
#
#
#         marker_f691c8b8c5854ed9709c7399bb478b54.bindPopup(popup_e136f1d6cd0bdcf233c45241c5ea8fc9)
#         ;
#
#
#
#
#             var marker_c5f9cb5a04b6c77e43654d0ef11376d5 = L.marker(
#                 [55.878662, 37.479251],
#                 {}
#             ).addTo(map_4aed2245c091a4b5e8d5d169e3b8028b);
#
#
#         var popup_d2c93744a7d632d3c0c7494b6c6ea4f1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4dee2cb30dfe7af8837cba216cd8d453 = $(`&lt;div id=&quot;html_4dee2cb30dfe7af8837cba216cd8d453&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Discovery 4.3&lt;/div&gt;`)[0];
#             popup_d2c93744a7d632d3c0c7494b6c6ea4f1.setContent(html_4dee2cb30dfe7af8837cba216cd8d453);
#
#
#         marker_c5f9cb5a04b6c77e43654d0ef11376d5.bindPopup(popup_d2c93744a7d632d3c0c7494b6c6ea4f1)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# А теперь отметим сразу все здания:

# %%
# подключаем библиотеку
from folium import Marker

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10, tiles='Cartodb Positron')

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его на карту
def create_marker(row):
    Marker([row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}"
    ).add_to(m)

# применяем функцию для создания маркера ко всем строкам датафрейма
df.apply(create_marker, axis=1)
    
# выводим карту
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba13f202fc777ba37f19fe39dd04b354 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba13f202fc777ba37f19fe39dd04b354&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ba13f202fc777ba37f19fe39dd04b354 = L.map(
#                 &quot;map_ba13f202fc777ba37f19fe39dd04b354&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b250458e6269260266f1cda4377ed15a = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ba13f202fc777ba37f19fe39dd04b354);
#
#
#             var marker_1748460f1e1d43a43d2d158361cd9536 = L.marker(
#                 [55.880803, 37.449824],
#                 {}
#             ).addTo(map_ba13f202fc777ba37f19fe39dd04b354);
#
#
#         var popup_6d88ed10c08eadb3dd0f48b927254c86 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c0a7274a49c0d67b3f947ba401453fbd = $(`&lt;div id=&quot;html_c0a7274a49c0d67b3f947ba401453fbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Капитолий 4.7&lt;/div&gt;`)[0];
#             popup_6d88ed10c08eadb3dd0f48b927254c86.setContent(html_c0a7274a49c0d67b3f947ba401453fbd);
#
#
#         marker_1748460f1e1d43a43d2d158361cd9536.bindPopup(popup_6d88ed10c08eadb3dd0f48b927254c86)
#         ;
#
#
#
#
#             var marker_812dc866e0fd6db3845af2674754f4ee = L.marker(
#                 [55.893082, 37.501263],
#                 {}
#             ).addTo(map_ba13f202fc777ba37f19fe39dd04b354);
#
#
#         var popup_bbb1d5ef27642d8be9af5c13adc990b5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ccf550c66094bd271d058eb8ea3a2a88 = $(`&lt;div id=&quot;html_ccf550c66094bd271d058eb8ea3a2a88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dexter 4.3&lt;/div&gt;`)[0];
#             popup_bbb1d5ef27642d8be9af5c13adc990b5.setContent(html_ccf550c66094bd271d058eb8ea3a2a88);
#
#
#         marker_812dc866e0fd6db3845af2674754f4ee.bindPopup(popup_bbb1d5ef27642d8be9af5c13adc990b5)
#         ;
#
#
#
#
#             var marker_e6f358baba0829b7ace4c34cb19e133f = L.marker(
#                 [55.909388, 37.539546],
#                 {}
#             ).addTo(map_ba13f202fc777ba37f19fe39dd04b354);
#
#
#         var popup_bc35700136cc396eb7aedfb154c90557 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_feb65a5662b7909fec69cedbc359bc4c = $(`&lt;div id=&quot;html_feb65a5662b7909fec69cedbc359bc4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;РИО 4.8&lt;/div&gt;`)[0];
#             popup_bc35700136cc396eb7aedfb154c90557.setContent(html_feb65a5662b7909fec69cedbc359bc4c);
#
#
#         marker_e6f358baba0829b7ace4c34cb19e133f.bindPopup(popup_bc35700136cc396eb7aedfb154c90557)
#         ;
#
#
#
#
#             var marker_8b04819fd67f11101d4a3c19047c8ec4 = L.marker(
#                 [55.869937, 37.469915],
#                 {}
#             ).addTo(map_ba13f202fc777ba37f19fe39dd04b354);
#
#
#         var popup_97bf641d9b00da1ceb24b58227f95511 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_154fee2c38e36df3d3c93d1265d28d86 = $(`&lt;div id=&quot;html_154fee2c38e36df3d3c93d1265d28d86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Экстрим 4.7&lt;/div&gt;`)[0];
#             popup_97bf641d9b00da1ceb24b58227f95511.setContent(html_154fee2c38e36df3d3c93d1265d28d86);
#
#
#         marker_8b04819fd67f11101d4a3c19047c8ec4.bindPopup(popup_97bf641d9b00da1ceb24b58227f95511)
#         ;
#
#
#
#
#             var marker_c348b93232c023de59b8bfddd1bef116 = L.marker(
#                 [55.878662, 37.479251],
#                 {}
#             ).addTo(map_ba13f202fc777ba37f19fe39dd04b354);
#
#
#         var popup_563daafd7e5787d8a3a0f7c252d0fb94 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_29d54f8a96ab34f8d6aae7d57240b7d3 = $(`&lt;div id=&quot;html_29d54f8a96ab34f8d6aae7d57240b7d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Discovery 4.3&lt;/div&gt;`)[0];
#             popup_563daafd7e5787d8a3a0f7c252d0fb94.setContent(html_29d54f8a96ab34f8d6aae7d57240b7d3);
#
#
#         marker_c348b93232c023de59b8bfddd1bef116.bindPopup(popup_563daafd7e5787d8a3a0f7c252d0fb94)
#         ;
#
#
#
#
#             var marker_91026289e77db180dd85e9353c87362a = L.marker(
#                 [55.893181, 37.50108],
#                 {}
#             ).addTo(map_ba13f202fc777ba37f19fe39dd04b354);
#
#
#         var popup_a355f0b5c66e5d24d7f1904eec970407 = L.popup({&quot;maxWidth&quot;: &quot;100%&quo

# %% [markdown]
# Здесь могут возникнуть проблемы:
#
# - Карта может долго отрисовываться, или рендериться (от англ. render, «выводить, отображать»), на слабых по производительности компьютерах или серверах;
# - Если на карте много точек, при уменьшении масштаба в ней будет сложно ориентироваться.
# - Из-за высокой нагрузки карта может зависать при передвижении по ней.
#
# Если отобразить на карте несколько тысяч точек, эти проблемы станут особенно заметны. Помогут кластеры — с их помощью можно поместить на карту много маркеров одновременно.
#
# Отметим все торговые центры на карте с помощью кластеров:

# %%
# импортируем карту и маркер
from folium import Map, Marker
# импортируем кластер
from folium.plugins import MarkerCluster

# moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10, tiles="Cartodb Positron")
# создаём пустой кластер, добавляем его на карту
marker_cluster = MarkerCluster().add_to(m)

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его в кластер marker_cluster
def create_clusters(row):
    Marker(
        [row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}",
    ).add_to(marker_cluster)

# применяем функцию create_clusters() к каждой строке датафрейма
df.apply(create_clusters, axis=1)

# выводим карту
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6ebd998fad7e39e4d7fa14b1184f7ff5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6ebd998fad7e39e4d7fa14b1184f7ff5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6ebd998fad7e39e4d7fa14b1184f7ff5 = L.map(
#                 &quot;map_6ebd998fad7e39e4d7fa14b1184f7ff5&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_08db6e9410b1e20056fdc3c1adbd0b8a = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6ebd998fad7e39e4d7fa14b1184f7ff5);
#
#
#             var marker_cluster_a8d7a96373da44778b056ad82cbbd18d = L.markerClusterGroup(
#                 {}
#             );
#             map_6ebd998fad7e39e4d7fa14b1184f7ff5.addLayer(marker_cluster_a8d7a96373da44778b056ad82cbbd18d);
#
#
#             var marker_f5d5bb36d200bf4056e65579ee464de4 = L.marker(
#                 [55.880803, 37.449824],
#                 {}
#             ).addTo(marker_cluster_a8d7a96373da44778b056ad82cbbd18d);
#
#
#         var popup_3f7be90be918755f2f54fb1ed6d7b9f9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_704e34a901329686cc2cc24663adaa66 = $(`&lt;div id=&quot;html_704e34a901329686cc2cc24663adaa66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Капитолий 4.7&lt;/div&gt;`)[0];
#             popup_3f7be90be918755f2f54fb1ed6d7b9f9.setContent(html_704e34a901329686cc2cc24663adaa66);
#
#
#         marker_f5d5bb36d200bf4056e65579ee464de4.bindPopup(popup_3f7be90be918755f2f54fb1ed6d7b9f9)
#         ;
#
#
#
#
#             var marker_860c20761cfd61a1e87273e88d38a147 = L.marker(
#                 [55.893082, 37.501263],
#                 {}
#             ).addTo(marker_cluster_a8d7a96373da44778b056ad82cbbd18d);
#
#
#         var popup_b8e9f70555a251e75253a47c5830c90c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_846ac4690b2aef647d993bc01bb34c04 = $(`&lt;div id=&quot;html_846ac4690b2aef647d993bc01bb34c04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dexter 4.3&lt;/div&gt;`)[0];
#             popup_b8e9f70555a251e75253a47c5830c90c.setContent(html_846ac4690b2aef647d993bc01bb34c04);
#
#
#         marker_860c20761cfd61a1e87273e88d38a147.bindPopup(popup_b8e9f70555a251e75253a47c5830c90c)
#         ;
#
#
#
#
#             var marker_d8e4441d7df44b2bc28d49131fd46178 = L.marker(
#                 [55.909388, 37.539546],
#                 {}
#             ).addTo(marker_cluster_a8d7a96373da44778b056ad82cbbd18d);
#
#
#         var popup_a31f5c07c67432ecbaf976c603441472 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_dc7e860798823548d78e178bd211a3bb = $(`&lt;div id=&quot;html_dc7e860798823548d78e178bd211a3bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;РИО 4.8&lt;/div&gt;`)[0];
#             popup_a31f5c07c67432ecbaf976c603441472.setContent(html_dc7e860798823548d78e178bd211a3bb);
#
#
#         marker_d8e4441d7df44b2bc28d49131fd46178.bindPopup(popup_a31f5c07c67432ecbaf976c603441472)
#         ;
#
#
#
#
#             var marker_41e82955c34fd4ec686cd564ae794436 = L.marker(
#                 [55.869937, 37.469915],
#                 {}
#             ).addTo(marker_cluster_a8d7a96373da44778b056ad82cbbd18d);
#
#
#         var popup_6e4d836f4ddac2430a2bd45fc49bffa5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0639b53a9db20843ccebfd77c6292000 = $(`&lt;div id=&quot;html_0639b53a9db20843ccebfd77c6292000&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Экстрим 4.7&lt;/div&gt;`)[0];
#             popup_6e4d836f4ddac2430a2bd45fc49bffa5.setContent(html_0639b53a9db20843ccebfd77c6292000);
#
#
#         marker_41e82955c34fd4ec686cd564ae794436.bindPopup(popup_6e4d836f4ddac2430a2bd45fc49bffa5)
#         ;
#
#
#
#
#             var marker_1d4541df374a35fedb251a0169764a38 = L.marker(
#                 [55.878662, 37.479251],
#                 {}
#             ).addTo(marker_cluster_a8d7a96373da44778b056ad82cbbd18d);
#
#
#         var popup_f8bf699a9d9dbe168d549775f0cb206f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});

# %% [markdown]
# Попробуйте увеличить масштаб с помощью колёсика мышки или кнопок на карте. Вы увидите, что кластеры автоматически перегруппировываются: при достаточном приближении из кластеров начнут «выпадать» отдельные маркеры с торговыми центрами. Всплывающие окна и подсказки для них реализованы точно так же, как и для отдельных маркеров.
